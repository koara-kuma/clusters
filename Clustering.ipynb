# %% [markdown]
# Comparison of different clustering algorithms
# **K-means clustering**, **spectral clustering** and **Leiden clustering(a modified version of louvain clustering algorithm)**.

# %%
# download louvain package
# !pip install louvain python-igraph leidenalg graphtools
# Out:
# Collecting louvain
#   Downloading louvain-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.4 MB/s eta 0:00:00
# Collecting python-igraph
#   Downloading python_igraph-0.10.5-py3-none-any.whl (9.1 kB)
# Collecting leidenalg
#   Downloading leidenalg-0.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 60.5 MB/s eta 0:00:00
# Collecting graphtools
#   Downloading graphtools-1.5.3-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 3.8 MB/s eta 0:00:00
# Collecting igraph<0.11,>=0.10.0 (from louvain)
#   Downloading igraph-0.10.5-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 78.9 MB/s eta 0:00:00
# Collecting texttable>=1.6.2 (from igraph<0.11,>=0.10.0->louvain)
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from graphtools) (1.22.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from graphtools) (1.10.1)
# Collecting pygsp>=0.5.1 (from graphtools)
#   Downloading PyGSP-0.5.1-py2.py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 66.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from graphtools) (1.2.2)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from graphtools) (0.18.3)
# Collecting tasklogger>=1.0 (from graphtools)
#   Downloading tasklogger-1.2.0-py3-none-any.whl (14 kB)
# Collecting Deprecated (from graphtools)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->graphtools) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->graphtools) (3.1.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated->graphtools) (1.14.1)
# Installing collected packages: texttable, igraph, Deprecated, tasklogger, python-igraph, pygsp, louvain, leidenalg, graphtools
# Successfully installed Deprecated-1.2.14 graphtools-1.5.3 igraph-0.10.5 leidenalg-0.10.0 louvain-0.8.0 pygsp-0.5.1 python-igraph-0.10.5 tasklogger-1.2.0 texttable-1.6.7

# %%
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('font', size=14)

import sklearn
import sklearn.cluster
import sklearn.datasets

import louvain
import graphtools as gt

import warnings
warnings.filterwarnings("ignore")
# Out:
# <ipython-input-2-6d121783bf76>:13: DeprecationWarning: This package has been superseded by the `leidenalg` package and will no longer be maintained. Please upgrade to the `leidenalg` package.
#   import louvain

# %% [markdown]
# ## Dataset generation
# First, we need to generate different datasets for clustering. We will use three datasets in $\mathbb{R}^2$: (**Note that the real data is usually high-dimensional, we use 2 dimensional dataset here just for better visualization**).
#
# * **Double-circles**: Dataset of the shape of two circles with the same center but different radius.
#
# * **Regular blobs**: several regular blobs, regular cluster shape.
#
# * **Uniform distribution**: Data generated from uniform distribution.
#
# You don't need to do anything at this step, since we have already implemented it for you.

# %%
np.random.seed(0)
# ============
# Generate datasets. We choose the size big enough to see the scalability
# of the algorithms, but not too big to avoid too long running times
# ============
n_samples = 1500

# Circles
noisy_circles = sklearn.datasets.make_circles(
    n_samples=n_samples,
    # Scale factor between inner and outer circle
    factor=.5,
    # Gaussian noise added to each point
    noise=.05)

# Uniform square
no_structure = (np.random.uniform(size=(n_samples, 2)), None)

# blobs with varied variances
varied = sklearn.datasets.make_blobs(n_samples=n_samples,
                                     cluster_std=[1.0, 2.5, 0.5],
                                     random_state=8)

# ============
# Associate each dataset with the correct # of clusters
# ============

default_base = {'n_clusters': 3}

generated_datasets = [
    (noisy_circles, {'n_clusters': 2}),
    (varied,      {}),
    (no_structure, {})]

fig, axes = plt.subplots(1,3,figsize=(12,4))

for i, (dataset, _) in enumerate(generated_datasets):
    ax = axes[i]
    X, y = dataset

    # normalize dataset for easier parameter selection
    X = sklearn.preprocessing.StandardScaler().fit_transform(X)
    ax.scatter(X[:,0], X[:,1], c=y, s = 0.5)

fig.tight_layout()

# %% [markdown]
# ## K-means algorithm
#
# **Useful tutorial**:
# * https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html

# %%
from sklearn.cluster import KMeans
def kmeans_skl(X, n_clusts):
    """\
    Kmeans algorithm

    Parameters:
    -----------
    X:
      dataset, numpy array of the shape (n_samples, n_features)
    n_clusts:
      number of clusters

    Return:
    ----------
    group:
      group identity of the clustering result, numpy array of the shape (n_samples,).
      e.g, if there are three data samples clustered into two groups, the return should be something like, numpy.array([0,1,1])
    """
    kmeans = KMeans(n_clusts)
    kmeans.fit(X)

    return kmeans.labels_

# %% [markdown]
# ## Spectral clustering algorithm
#
# **Useful tutorial**:
# * https://scikit-learn.org/stable/modules/generated/sklearn.cluster.SpectralClustering.html
#
# **Note**:
# * Make sure to set the `affinity` in spectral clustering function to `"nearest_neighbors"`. The default setting in sklearn was `"rbf"`, which will not produce a very good result.

# %%
from sklearn.cluster import SpectralClustering
def spectral_skl(X, n_clusts):
    """\
    spectral clustering algorithm

    Parameters:
    -----------
    X:
      dataset, numpy array of the shape (n_samples, n_features)
    n_clusts:
      number of clusters

    Return:
    ----------
    group:
      group identity of the clustering result, numpy array of the shape (n_samples,).
      e.g, if there are three data samples clustered into two groups, the return should be something like, numpy.array([0,1,1])
    """

    spectral = SpectralClustering(n_clusters=n_clusts, affinity = 'nearest_neighbors')
    spectral.fit(X)


    return spectral.labels_

# %% [markdown]
# ## Leiden algorithm
# Leiden algorithm is a graph based algorithm, instead of specifying the number of clusters, leiden algorithm use resolution to control the size of clusters.

# %%
def leiden(X, resolution=0.01):
    """\
    leiden clustering algorithm.

    Parameters:
    -----------
    X:
      dataset, numpy array of the shape (n_samples, n_features)
    resolution:
      resolution term

    Return:
    ----------
    group:
      group identity of the clustering result, numpy array of the shape (n_samples,).
      e.g, if there are three data samples clustered into two groups, the return should be something like, numpy.array([0,1,1])
    """

    G = gt.Graph(X)
    G_igraph = G.to_igraph()
    part = louvain.find_partition(G_igraph, louvain.RBConfigurationVertexPartition,
                                  weights="weight", resolution_parameter=resolution)
    groups = np.array(part.membership)

    return groups

# %% [markdown]
# ## Test the algorithms in different datasets
# We will test the algorithms in different datasets. Run the code below and see how the algorithms perform under different circumstances. Submit the plots that you generate. Discuss with your collaborator and briefly discribe what you find in you submission.

# %%
fig, axes = plt.subplots(3,3, figsize=(15, 10))
plot_title = True

titles = ['KMeans', 'Spectral', 'Leiden']

# loop through all three datasets
for i_dataset, (dataset, cluster_params) in enumerate(generated_datasets):

    params = default_base.copy()
    params.update(cluster_params)

    X, y = dataset

    # normalize dataset

    # ============
    # Run clustering algorithms
    # ============
    clusters = []

    # KMeans
    clusters.append(kmeans_skl(X, params["n_clusters"]))

    # Spectral Clustering
    clusters.append(kmeans_skl(X, params["n_clusters"]))

    clusters.append(leiden(X))

    # ============
    # Plot clustering results
    # ============
    row_axes = axes[i_dataset]

    for i, ax in enumerate(row_axes.flatten()):
        curr_cluster = clusters[i]
        if plot_title:
            curr_title = '{}'.format(titles[i])
        else:
            curr_title = None

        ax.scatter(X[:,0], X[:,1], c=curr_cluster, s = 0.5)
        ax.set_title(curr_title)

    plot_title=False
fig.tight_layout()

# %% [markdown]
# ## Running time
# Next we will test the running time of the algorithms with datasets of different sizes. We will use the **Regular blobs** shaped dataset with different number of samples: 1000, 5000, 10000 and see how the running time changes. Note that Leiden is faster than others

# %%
np.random.seed(0)

# generated datasets
generated_datasets = [(sklearn.datasets.make_blobs(n_samples=n_samples, random_state=8, cluster_std=1), n_samples) for n_samples in [1000, 5000, 10000]]

fig, axes = plt.subplots(1,3,figsize=(12,4))

for i, (dataset, _) in enumerate(generated_datasets):
    ax = axes[i]
    X, y = dataset

    # normalize dataset for easier parameter selection
    X = sklearn.preprocessing.StandardScaler().fit_transform(X)
    ax.scatter(X[:,0], X[:,1], c=y, s = 0.5)

fig.tight_layout()

# %%
fig, axes = plt.subplots(3,3, figsize=(15, 10))
plot_title = True


titles = ['KMeans', 'Spectral', 'Leiden']

# loop through all three datasets
for i_dataset, (dataset, n_samples) in enumerate(generated_datasets):
    print("dataset: "+str(i_dataset)+", number of samples: " + str(n_samples))

    params = default_base.copy()
    params.update(cluster_params)

    X, y = dataset

    # normalize dataset

    # ============
    # Run clustering algorithms
    # ============
    clusters = []

    # KMeans
    tic = time.time()
    clusters.append(kmeans_skl(X, params["n_clusters"]))

    print("\t running time for k-means(sec):", time.time() - tic)

    # Spectral Clustering
    tic = time.time()
    clusters.append(spectral_skl(X, params["n_clusters"]))

    print("\t running time for spectral clustering(sec):", time.time() - tic)

    # Leiden
    tic = time.time()
    clusters.append(leiden(X))

    print("\t running time for leiden algorithm(sec):", time.time() - tic)

    # ============
    # Plot clustering results
    # ============
    row_axes = axes[i_dataset]

    for i, ax in enumerate(row_axes.flatten()):
        curr_cluster = clusters[i]
        if plot_title:
            curr_title = '{}'.format(titles[i])
        else:
            curr_title = None

        ax.scatter(X[:,0], X[:,1], c=curr_cluster, s = 0.5)
        ax.set_title(curr_title)



    plot_title=False
fig.tight_layout()
# Out:
# dataset: 0, number of samples: 1000
# 	 running time for k-means(sec): 0.017539024353027344
# 	 running time for spectral clustering(sec): 1.0399293899536133
# 	 running time for leiden algorithm(sec): 0.31143641471862793
# dataset: 1, number of samples: 5000
# 	 running time for k-means(sec): 0.337998628616333
# 	 running time for spectral clustering(sec): 3.0443344116210938
# 	 running time for leiden algorithm(sec): 0.29105544090270996
# dataset: 2, number of samples: 10000
# 	 running time for k-means(sec): 0.37361812591552734
# 	 running time for spectral clustering(sec): 7.497729063034058
# 	 running time for leiden algorithm(sec): 0.8817119598388672

# %% [markdown]
# ## Additional reading:
# * **SpectralNet** is a fast implementation of spectral clustering algorithm with deep neural network. It has the advantage of spectral clustering and also scales well to large datasets: https://arxiv.org/abs/1801.01587
#
# * **Quora discussion** about the pros and cons of spectral clustering and k-means: https://www.quora.com/What-are-the-advantages-of-spectral-clustering-over-k-means-clustering
